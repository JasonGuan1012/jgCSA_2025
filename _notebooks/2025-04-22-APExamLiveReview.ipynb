# %% [markdown]
# ---
# layout: post
# title: AP Exam Live Review
# description:
# type: issues
# courses: { csa: {week: 25} }
# comments: true
# permalink: /APExam
# toc: true
# ---

# %% [markdown]
# # **Each Unit Summary**

# %% [markdown]
# <body>
#     <style>
#         @use postcss-nested;
#         .shadow-button-set {
#           margin: 0;
#           display: flex;
#           flex-direction: column;
#           align-items: flex-start;
#           gap: 2.5vmin;
#           & > li {
#             display: inline-flex;
#             background: black;
#             &:is(:hover, :focus-within) > button:not(:active) {
#               --distance: -10px;
#             }
#           }
#           & button {
#             appearance: none;
#             outline: none;
#             font-size: 3vmin;
#             border: 3px solid black;
#             background: white;
#             --distance: 0;
#             transform: translateX(var(--distance)) translateY(var(--distance));
#             @media (prefers-reduced-motion: no-preference) {
#               will-change: transform;
#               transition: transform .2s ease;
#             }
#             &:hover {
#               box-shadow: 0 0 10px #88bc4c, 0 0 20px #88bc4c, 0 0 30px #88bc4c;
#             }
#           }
#         }
#         * {
#           box-sizing: border-box;
#           margin: 0;
#         }
#         html {
#           block-size: 100%;
#         }
#         body {
#           min-block-size: 100%;
#           font-family: system-ui, sans-serif;
#           display: grid;
#           place-content: center;
#         }
#     </style>
#     <ul class="shadow-button-set">
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit1Summary_IPYNB_2_.html'">Unit 1 - Primitive Types</button></li>
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit2Summary_IPYNB_2_.html'">Unit 2 - Using Objects</button></li>
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit3Summary_IPYNB_2_.html'">Unit 3 - Boolean</button></li>
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit4Summary_IPYNB_2_.html'">Unit 4 - Iteration</button></li>
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit5Summary_IPYNB_2_.html'">Unit 5 - Classes</button></li>
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit6Summary_IPYNB_2_.html'">Unit 6 - Arrays</button></li>
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit7Summary_IPYNB_2_.html'">Unit 7 - ArrayList</button></li>
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit8Summary_IPYNB_2_.html'">Unit 8 - 2D Arrays</button></li>
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2024/10/11/Unit9Summary_IPYNB_2_.html'">Unit 9 - Java Inheritance</button></li>
#         <li><button onclick="location.href='https://nighthawkcoders.github.io/portfolio_2025/recursion/p3_recursion_part1'">Unit 10 - Recursion</button></li>
#     </ul>
# </body>

# %% [markdown]
# <br><br>

# %% [markdown]
# # **2020 FRQ Practice**

# %% [markdown]
# <br>
# <body>
#     <style>
#         @use postcss-nested;
#         .shadow-button-set {
#           margin: 0;
#           display: flex;
#           flex-direction: column;
#           align-items: flex-start;
#           gap: 2.5vmin;
#           & > li {
#             display: inline-flex;
#             background: black;
#             &:is(:hover, :focus-within) > button:not(:active) {
#               --distance: -10px;
#             }
#           }
#           & button {
#             appearance: none;
#             outline: none;
#             font-size: 3vmin;
#             border: 3px solid black;
#             background: white;
#             --distance: 0;
#             transform: translateX(var(--distance)) translateY(var(--distance));
#             @media (prefers-reduced-motion: no-preference) {
#               will-change: transform;
#               transition: transform .2s ease;
#             }
#             &:hover {
#               box-shadow:  0 0 10px #335f7f,  0 0 20px #335f7f,  0 0 30px #001f3f;
#             }
#           }
#         }
#         * {
#           box-sizing: border-box;
#           margin: 0;
#         }
#         html {
#           block-size: 100%;
#         }
#         body {
#           min-block-size: 100%;
#           font-family: system-ui, sans-serif;
#           display: grid;
#           place-content: center;
#         }
#     </style>
#     <ul class="shadow-button-set">
#         <li><button onclick="location.href='https://jasonguan1012.github.io/jgCSA_2025/2020FRQ'">2020 FRQ Practice</button></li>
#     </ul>
# </body>
