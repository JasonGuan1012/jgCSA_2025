# %% [markdown]
# ---
# layout: post
# title: Sprint 2 - Review Ticket ← ← ←
# description:  Student Teach and Software Development Objectives for Sprint 2 live reivew
# type: issues
# courses: { csa: {week: 7} }
# comments: true
# ---

# %% [markdown]
# <body>
#     <style>
#         @use postcss-nested;
#         .shadow-button-set {
#           margin: 0;
#           display: flex;
#           flex-direction: column;
#           align-items: flex-start;
#           gap: 2.5vmin;
#           & > li {
#             display: inline-flex;
#             background: black;
#             &:is(:hover, :focus-within) > button:not(:active) {
#               --distance: -10px;
#             }
#           }
#           & button {
#             appearance: none;
#             outline: none;
#             font-size: 3vmin;
#             border: 3px solid black;
#             background: white;
#             --distance: 0;
#             transform: translateX(var(--distance)) translateY(var(--distance));
#             @media (prefers-reduced-motion: no-preference) {
#               will-change: transform;
#               transition: transform .2s ease ;
#             }
#           }
#         }
#         &:hover {
#             box-shadow: 0 0 10px #88bc4c, 0 0 20px #88bc4c, 0 0 30px #88bc4c;
#         }
#         * {
#           box-sizing: border-box;
#           margin: 0;
#         }
#         html {
#           block-size: 100%;
#         }
#         body {
#           min-block-size: 100%;
#           font-family: system-ui, sans-serif;
#           display: grid;
#           place-content: center;
#         }
#     </style>
#     <ul class="shadow-button-set">
#         <li><button onclick="location.href='https://example.com/new-game'">Unit 2 - Using Objects</button></li>
#         <li><button onclick="location.href='https://example.com/continue'">Unit 3 - Boolean</button></li>
#         <li><button onclick="location.href='https://example.com/online'">Unit 4 - Iteration</button></li>
#         <li><button onclick="location.href='https://example.com/settings'">Unit 5 - Classes</button></li>
#         <li><button onclick="location.href='https://example.com/quit'">Unit 6 - Arrays</button></li>
#         <li><button onclick="location.href='https://example.com/settings'">Unit 7 - ArrayList</button></li>
#         <li><button onclick="location.href='https://example.com/quit'">Unit 8 - 2D Arrays</button></li>
#         <li><button onclick="location.href='https://example.com/quit'">Unit 9 - Java Inheritance</button></li>
#     </ul>
#
# </body>
